# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
image = cv2.imread("Images\people2.jpg")
plt.imshow(image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Boss Baby\AppData\Local\Temp\ipykernel_7700\1554156887.py:1: SyntaxWarning: invalid escape sequence '\p'
#   image = cv2.imread("Images\people2.jpg")

# %%
image.shape,image.shape[0]*image.shape[1]*3
# Out:
# ((537, 1023, 3), 1648053)

# %%
image_blob = cv2.dnn.blobFromImage(image=image,scalefactor=1.0/255,size=(image.shape[1],image.shape[0]))

# %%
type(image_blob), image_blob.shape
# Out:
# (numpy.ndarray, (1, 3, 537, 1023))
